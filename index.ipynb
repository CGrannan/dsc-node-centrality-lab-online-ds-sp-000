# %% [markdown]
# # Network Dynamics: Node Centrality - Lab
#
# ## Introduction
#
# In this lab, you'll get a chance to practice implementing and interpreting the centrality metrics discussed in the previous lesson by investigating the social network from Game of Thrones!
#
# ## Objectives
# You will be able to:
# - Compare and calculate degree, closeness, betweenness, and eigenvector centrality measures
# - Interpret characteristics of certain nodes based on their centrality metrics

# %% [markdown]
# ## Character Interaction Graph Data
#
# A. J. Beveridge and J. Shan created a network from George R. Martin's "A song of ice and fire" by extracting relationships between characters of the story. [The dataset is available at Github](https://github.com/mathbeveridge/asoiaf). Relationships between characters were formed every time a character's name appears within 15 words of another character. This was designed as an approximate metric for character's interactions with each other. The results of this simple analysis are quite profound and produce interesting visuals such as this graph:
#
# <img src="images/got.png" width=800>
#
# With that, it's your turn to start investigating the most central characters!

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline

# %% [markdown]
# ##  Load the dataset
#
# Start by loading the dataset as a pandas DataFrame. From this, you'll then create a network representation of the dataset using NetworkX.
#
# The dataset is stored in the file `'asoiaf-all-edges.csv'`.

# %%
# Load edges into dataframes
df = pd.read_csv('asoiaf-all-edges.csv')

# Print the first five rows
df.head()
# Out:
#            Source            Target        Type  id  weight
# 0  Addam-Marbrand     Brynden-Tully  Undirected   0       3
# 1  Addam-Marbrand  Cersei-Lannister  Undirected   1       3
# 2  Addam-Marbrand       Gyles-Rosby  Undirected   2       3
# 3  Addam-Marbrand   Jaime-Lannister  Undirected   3      14
# 4  Addam-Marbrand      Jalabhar-Xho  Undirected   4       3

# %% [markdown]
# ## Create a Graph
#
# - Instantiate an empty graph
# - Iterate through the data and create appropriate edges to the empty graph you instantiated above. Be sure to add the weight to each edge

# %%
# Create an empty graph instance
G = nx.Graph()

# Read edge lists into dataframes
for row in df.index:
    G.add_edge(df.Source[row], df.Target[row], weight=df.weight[row])

# %% [markdown]
# ## Calculate Degree
#
# To start the investigation of the most central characters in the books, calculate the degree centrality for each character. Then create a bar graph of the top 10 characters according to degree centrality.

# %%
pd.DataFrame.from_dict(nx.degree_centrality(G), orient='index').sort_values(by=0, ascending=False).head(10).plot(kind='barh')
plt.title('Top 10 Characters by Degree Centrality');

# %% [markdown]
# ## Closeness Centrality
#
# Repeat the above exercise for the top 10 characters according to closeness centrality.

# %%
pd.DataFrame.from_dict(nx.closeness_centrality(G), orient='index').sort_values(by=0, ascending=False).head(10).plot(kind='barh')
plt.title('Top 10 Characters by Closeness Centrality');

# %% [markdown]
# ## Betweeness Centrality
#
# Repeat the process one more time for betweeness centrality.

# %%
pd.DataFrame.from_dict(nx.betweenness_centrality(G), orient='index').sort_values(by=0, ascending=False).head(10).plot(kind='barh')
plt.title('Top 10 Characters by Betweeness Centrality');

# %% [markdown]
# ## Putting it All Together
#
# Great! Now put all of these metrics together along with eigenvector centrality. Combine all four metrics into a single dataframe for each character.

# %%
degrees = nx.degree_centrality(G)
closeness = nx.closeness_centrality(G)
betweeness = nx.betweenness_centrality(G)
eigs = nx.eigenvector_centrality(G)
centrality_df = pd.DataFrame([degrees, closeness, betweeness, eigs]).transpose()
centrality_df.columns = ['degrees', 'closeness', 'betweeness', 'eigs']
centrality_df = centrality_df.sort_values(by='eigs', ascending=False)
centrality_df.head()
# Out:
#                     degrees  closeness  betweeness      eigs
# Tyrion-Lannister   0.153459   0.476333    0.162191  0.251558
# Cersei-Lannister   0.122013   0.454545    0.088704  0.235771
# Jaime-Lannister    0.127044   0.451961    0.100838  0.226339
# Joffrey-Baratheon  0.086792   0.433952    0.031759  0.214376
# Sansa-Stark        0.094340   0.433007    0.048691  0.205842

# %% [markdown]
# ## Identifying Key Players
#
# While centrality can tell us a lot, you've also begun to see how certain individuals may not be the most central characters, but can be pivotal in the flow of information from one community to another. In the previous lesson, such nodes were labeled as 'bridges' acting as the intermediaries between two clusters. Try and identify such characters from this dataset.

# %%
centrality_df['bridge_liklieness'] = centrality_df.betweeness/centrality_df.degrees
centrality_df = centrality_df.sort_values('bridge_liklieness', ascending=False)
centrality_df.loc[centrality_df.bridge_liklieness > 1]
# Out:
#                       degrees  closeness  betweeness      eigs  \
# Aggar                0.005031   0.269036    0.007997  0.001665
# Alleras              0.010063   0.272915    0.014199  0.002928
# Theon-Greyjoy        0.083019   0.423323    0.111283  0.102481
# Jon-Snow             0.143396   0.445378    0.192120  0.144211
# Cutjack              0.003774   0.255135    0.005028  0.001404
# Red-Oarsman          0.003774   0.261255    0.005025  0.001042
# Daenerys-Targaryen   0.091824   0.383317    0.118418  0.063043
# Victarion-Greyjoy    0.030189   0.333753    0.036451  0.009395
# Pate-(novice)        0.008805   0.215097    0.010042  0.000175
# Tyrion-Lannister     0.153459   0.476333    0.162191  0.251558
# Asha-Greyjoy         0.031447   0.351770    0.033025  0.023000
# Rennifer-Longwaters  0.002516   0.311642    0.002516  0.007930
# Florian-the-Fool     0.002516   0.302511    0.002516  0.007212
# Horas-Redwyne        0.002516   0.302973    0.002516  0.007511
# Ricasso              0.002516   0.228186    0.002516  0.000431
# Gerrick-Kingsblood   0.002516   0.308498    0.002516  0.005053
# Brandon-Norrey       0.002516   0.308498    0.002516  0.005053
#
#                      bridge_liklieness
# Aggar                         1.589358
# Alleras                       1.411040
# Theon-Greyjoy                 1.340458
# Jon-Snow                      1.339782
# Cutjack                       1.332494
# Red-Oarsman                   1.331654
# Daenerys-Targaryen            1.289621
# Victarion-Greyjoy             1.207431
# Pate-(novice)                 1.140428
# Tyrion-Lannister              1.056901
# Asha-Greyjoy                  1.050187
# Rennifer-Longwaters           1.000000
# Florian-the-Fool              1.000000
# Horas-Redwyne                 1.000000
# Ricasso                       1.000000
# Gerrick-Kingsblood            1.000000
# Brandon-Norrey                1.000000

# %% [markdown]
# ## Drawing the Graph
#
# To visualize all of these relationships, draw a graph of the network.

# %%
edge_labels = nx.get_edge_attributes(G, 'weight')
figure = plt.figure(figsize=(20,20))
nx.draw(G, os=nx.spring_layout(G), with_labels=True,
        alpha=.8, node_color='#1cf0c7', node_size=700)
nx.draw_networkx_edge_labels(G,pos=nx.spring_layout(G), edge_labels=edge_labels);
# Out:
# /Users/rlathbury/anaconda3/envs/learn-env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# ## Subsetting the Graph
#
# As you can see, the above graph is undoubtedly noisy, making it difficult to discern any useful patterns. As such, reset the graph and only add edges whose weight is 75 or greater. From there, redraw the graph. To further help with the display, try using `nx.spring_layout(G)` for the position. To jazz it up, try and recolor those nodes which you identified as bridge or bottleneck nodes to communication.

# %%
colors = []
G = nx.Graph()
for row in df.index:
    source = df['Source'][row]
    target = df['Target'][row]
    weight = df['weight'][row]
    if weight >= 75:
        G.add_edge(source,target, weight=weight)
edge_labels = nx.get_edge_attributes(G,'weight')
for node in G.nodes:
    if node in centrality_df.index[:10]:
        colors.append('#ffd43d')
    else:
        colors.append('#1cf0c7')
plt.figure(figsize=(18,10))
nx.draw(G, with_labels=True, pos=nx.spring_layout(G),
        alpha=.8, node_color=colors, node_size=1500)
nx.draw_networkx_edge_labels(G,pos=nx.spring_layout(G), edge_labels=edge_labels)
# Out:
# /Users/rlathbury/anaconda3/envs/learn-env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# {('Aemon-Targaryen-(Maester-Aemon)',
#   'Jon-Snow'): Text(-0.3076627213072135, 0.25007994845776416, '110'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Samwell-Tarly'): Text(-0.32962784501523407, 0.27910361779807125, '99'),
#  ('Jon-Snow',
#   'Bran-Stark'): Text(-0.24549807021047854, 0.248450710311202, '90'),
#  ('Jon-Snow',
#   'Jeor-Mormont'): Text(-0.31947726030628054, 0.21006801636750905, '174'),
#  ('Jon-Snow',
#   'Mance-Rayder'): Text(-0.33900503498781925, 0.2195409925007571, '112'),
#  ('Jon-Snow', 'Pypar'): Text(-0.3101729293597857, 0.27048672328803247, '77'),
#  ('Jon-Snow',
#   'Robb-Stark'): Text(-0.26549852019020637, 0.19940633270881183, '91'),
#  ('Jon-Snow',
#   'Samwell-Tarly'): Text(-0.32455858100404855, 0.2482086687117364, '228'),
#  ('Jon-Snow',
#   'Stannis-Baratheon'): Text(-0.29507451902402226, 0.1436089423226157, '91'),
#  ('Jon-Snow', 'Ygritte'): Text(-0.3491192111972276, 0.24099579864622395, '80'),
#  ('Samwell-Tarly',
#   'Gilly'): Text(-0.3770224820081528, 0.308910883733141, '84'),
#  ('Arya-Stark',
#   'Gendry'): Text(0.1627216915284026, -0.24748236378305005, '82'),
#  ('Arya-Stark',
#   'Hot-Pie'): Text(0.1381860037996803, -0.2604153964543963, '76'),
#  ('Arya-Stark',
#   'Sansa-Stark'): Text(0.11367149235207427, -0.1758672268122188, '155'),
#  ('Sansa-Stark',
#   'Cersei-Lannister'): Text(0.06002764689522766, -0.10515158658554188, '95'),
#  ('Sansa-Stark',
#   'Joffrey-Baratheon'): Text(0.08373172210803281, -0.10843337619864163, '222'),
#  ('Sansa-Stark',
#   'Tyrion-Lannister'): Text(0.10244656525745793, -0.09604787192264229, '118'),
#  ('Barristan-Selmy',
#   'Daenerys-Targaryen'): Text(0.9694804149546984, -0.5716260506753164, '83'),
#  ('Daenerys-Targaryen',
#   'Drogo'): Text(0.9401543067184339, -0.5801069369087091, '123'),
#  ('Daenerys-Targaryen',
#   'Hizdahr-zo-Loraq'): Text(0.9741488168002126, -0.5405873478260843, '96'),
#  ('Daenerys-Targaryen',
#   'Jorah-Mormont'): Text(0.9369345755795478, -0.5383694731571746, '161'),
#  ('Bran-Stark',
#   'Hodor'): Text(-0.17856819724854953, 0.2991161147569058, '209'),
#  ('Bran-Stark',
#   'Jojen-Reed'): Text(-0.1726598379826889, 0.3209945525849362, '112'),
#  ('Bran-Stark',
#   'Luwin'): Text(-0.15589996488218516, 0.3060074017952663, '116'),
#  ('Bran-Stark',
#   'Meera-Reed'): Text(-0.19653669810396496, 0.313221280255894, '123'),
#  ('Bran-Stark',
#   'Rickon-Stark'): Text(-0.15465188850882763, 0.2859754156820645, '129'),
#  ('Bran-Stark',
#   'Robb-Stark'): Text(-0.20840313310465686, 0.2286720436485845, '169'),
#  ('Robb-Stark',
#   'Catelyn-Stark'): Text(-0.19493799075051682, 0.12812294434298133, '128'),
#  ('Robb-Stark',
#   'Theon-Greyjoy'): Text(-0.2941204213880655, 0.1585911676006656, '76'),
#  ('Brienne-of-Tarth',
#   'Jaime-Lannister'): Text(0.139732692733261, -0.11909796456314671, '111'),
#  ('Jaime-Lannister',
#   'Cersei-Lannister'): Text(0.06691741893284925, -0.08865108053171572, '130'),
#  ('Jaime-Lannister',
#   'Tyrion-Lannister'): Text(0.10933633729507951, -0.07954736586881613, '113'),
#  ('Bronn',
#   'Tyrion-Lannister'): Text(0.13021343074660588, -0.030002525441012257, '137'),
#  ('Tyrion-Lannister',
#   'Cersei-Lannister'): Text(0.06822694324530101, -0.06777628950654872, '209'),
#  ('Tyrion-Lannister',
#   'Joffrey-Baratheon'): Text(0.09193101845810617, -0.07105807911964848, '219'),
#  ('Tyrion-Lannister',
#   'Tywin-Lannister'): Text(0.14775581506879773, -0.062179884684399014, '117'),
#  ('Tyrion-Lannister',
#   'Varys'): Text(0.1465694878993962, -0.04294109213272642, '107'),
#  ('Catelyn-Stark',
#   'Eddard-Stark'): Text(-0.1249394753488559, 0.02014923974834888, '88'),
#  ('Eddard-Stark',
#   'Cersei-Lannister'): Text(-0.03129926369899606, -0.056599873656259445, '91'),
#  ('Eddard-Stark',
#   'Petyr-Baelish'): Text(-0.10832218042328212, -0.072870445763049, '85'),
#  ('Eddard-Stark',
#   'Robert-Baratheon'): Text(-0.08240213633325641, -0.047327722438707684, '334'),
#  ('Cersei-Lannister',
#   'Joffrey-Baratheon'): Text(0.049512100095875894, -0.08016179378254806, '173'),
#  ('Cersei-Lannister',
#   'Margaery-Tyrell'): Text(0.0157522838341382, -0.11517010355107787, '79'),
#  ('Cersei-Lannister',
#   'Robert-Baratheon'): Text(-0.02529484775118961, -0.06760785295189654, '134'),
#  ('Cersei-Lannister',
#   'Tommen-Baratheon'): Text(0.03505387120385782, -0.05486665048174867, '111'),
#  ('Joffrey-Baratheon',
#   'Tommen-Baratheon'): Text(0.05875794641666297, -0.05814844009484843, '77'),
#  ('Robert-Baratheon',
#   'Renly-Baratheon'): Text(-0.13785543606941825, -0.03348195311716233, '80'),
#  ('Davos-Seaworth',
#   'Stannis-Baratheon'): Text(-0.3033756145274433, 0.03892587409860086, '131'),
#  ('Stannis-Baratheon',
#   'Melisandre'): Text(-0.3258599849465428, 0.0442547899727906, '87'),
#  ('Stannis-Baratheon',
#   'Renly-Baratheon'): Text(-0.24343436625270148, 0.0297023403869111, '110'),
#  ('Ramsay-Snow',
#   'Theon-Greyjoy'): Text(-0.4025335692350026, 0.12970997745955504, '101')}

# %% [markdown]
# ## Summary
#
# In this lab, we looked at different centrality measures of the graph data for the ASIOF dataset. We also compared these measures to see how they correlate with each other. We also saw in practice, the difference between taking the weighted centrality measures and how it may effect the results.
